# %% [markdown]
# Most of ML models are based on Euclidean distance, and if we do not scale the variable, then it will cause some issue.

# %%
# # Euclidian Distance

# %% [markdown]
# <img src='euclidian-distance.jpg' width=350 hieght=350>
#
# There are many ways to perform feature scaling in ML e.g.
#
#         1.Standardization
#         2.Normalization
#
# ![image.png](attachment:image.png)

# %% [markdown]
# X_train=ss.fit_transform(X_train)
#
# For test dataset, we will directly apply transform() function instead of fit_transform() because it is already done in training set.
#
# X_test= ss.transform(X_test)
