# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix,f1_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import re

# %%
df = pd.read_csv("twitter_hate_speech_train_E6oV3lV.csv")
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
hate_tweet = df[df.label == 1]
hate_tweet.head()
# Out:
#     id  label                                              tweet
# 13  14      1  @user #cnn calls #michigan middle school 'buil...
# 14  15      1  no comment!  in #australia   #opkillingbay #se...
# 17  18      1                             retweet if you agree!
# 23  24      1    @user @user lumpy says i am a . prove it lumpy.
# 34  35      1  it's unbelievable that in the 21st century we'...

# %%
normal_tweet = df[df.label == 0]
normal_tweet.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
from os import path

# %%
from PIL import Image

# %% [raw]
# PIL:
# Python Imaging Library is a free and open-source additional library for the Python that adds support for opening, manipulating, and saving many different image file formats
# -provides the python interpreter with image editing capabilities.
# -PIL.Image.open() Opens and identifies the given image file
#
# # Imports PIL module
# from PIL import Image
#
# # open method used to open different extension image file
# im = Image.open(r"C:\Users\System-Pc\Desktop\ybear.jpg")
#
# # This method will show image in any image viewer
# im.show()

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text=" ".join(x for x in hate_tweet.tweet)
#Joining with space separator

# %%
wordcloud=WordCloud(max_font_size=50,max_words=100, background_color='black').generate(text)

# %%
fig=plt.figure(figsize=(20,10))
plt.imshow(wordcloud,interpolation='bilinear')
# Display data as an image, i.e., on a 2D regular raster.
plt.axis('off')
# Convenience method to get or set some axis properties
plt.show()

# %%
df.head(2)
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...

# %%
df_stat=df[['label','tweet']].groupby('label').count().reset_index()

# %%
df_stat.columns
# Out:
# Index(['label', 'tweet'], dtype='object')

# %%
df_stat.head(2)
# Out:
#    label  tweet
# 0      0  29720
# 1      1   2242

# %%
df_stat['percentage']=(df_stat['tweet']/df_stat.tweet.sum())*100

# %%
df_stat.head(2)
# Out:
#    label  tweet  percentage
# 0      0  29720    92.98542
# 1      1   2242     7.01458

# %% [raw]
# re.sub(pattern, repl, string, count=0, flags=0)
# -pattern:pattern to seach
# -repl:character to replace with
# -string:into which search performed
# -count:no of occurance to change

# %%
def process_tweet(tweet):
    return " ".join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])", " ",tweet.lower()).split())

# %%
df['processed_tweets'] = df['tweet'].apply(process_tweet)
df.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                     processed_tweets
# 0  when a father is dysfunctional and is so selfi...
# 1  thanks for lyft credit i can t use cause they ...
# 2                                bihday your majesty
# 3      model i love u take with u all the time in ur
# 4                  factsguide society now motivation

# %%
count_non_fraud=df[df['label']==0]['processed_tweets'].count()
count_non_fraud
# Out:
# 29720

# %%
df_fraud=df[df['label']==1]
df_non_fraud=df[df['label']==0]

# %%
df_class_fraud_oversample=df_fraud.sample(count_non_fraud,replace=True)

# %% [raw]
# here the first parameter is termed as 'n', which should be an integer value
# n : int, optional
#     Number of items from axis to return. Cannot be used with `frac`.
#     Default = 1 if `frac` = None.
#
# replace : bool, default False
# Allow or disallow sampling of the same row more than once.

# %%
df_oversampled = pd.concat([df_non_fraud, df_class_fraud_oversample], axis=0)

# %%
print(df_oversampled['label'].value_counts())
# Out:
# 1    29720
# 0    29720
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df_oversampled['processed_tweets']
y = df_oversampled['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = None)

# %% [raw]
# stratify : array-like, default=None
#     If not None, data is split in a stratified fashion, using this as
#     the class labels.

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %% [raw]
# TfidfTransformer:
# Transform a count matrix to a normalized tf or tf-idf representation
#
# Tf means term-frequency while tf-idf means term-frequency times inverse document-frequency.
# This is a common term weighting scheme in information retrieval, that has also found good use in document classification.
#
# The goal of using tf-idf instead of the raw frequencies of occurrence of a
# token in a given document is to scale down the impact of tokens that occur
# very frequently in a given corpus and that are hence empirically less
# informative than features that occur in a small fraction of the training
# corpus.
#
# CountVectorizer:
# Convert a collection of text documents to a matrix of token counts

# %%
count_vect=CountVectorizer(stop_words='english')

# %%
transformer = TfidfTransformer(norm='l2',sublinear_tf=True)

# %%
X_train_cv=count_vect.fit_transform(X_train)
X_train_tfidf=transformer.fit_transform(X_train_cv)

# %%
X_train_cv.shape, X_train_tfidf.shape
# Out:
# ((47552, 33927), (47552, 33927))

# %%
X_test_cv= count_vect.transform(X_test)
X_test_tfidf= transformer.transform(X_test_cv)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rfc=RandomForestClassifier(n_estimators=500)
model_rfc.fit(X_train_tfidf,y_train)
pred_rfc=model_rfc.predict(X_test_tfidf)

# %%
# creating confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,pred_rfc))
# Out:
# [[5790  152]
#  [   0 5946]]

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      5942
#            1       0.98      1.00      0.99      5946
#
#     accuracy                           0.99     11888
#    macro avg       0.99      0.99      0.99     11888
# weighted avg       0.99      0.99      0.99     11888

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier(random_state=1,learning_rate=0.9)
model_xgb.fit(X_train_tfidf,y_train)
# Out:
# [16:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.9, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=1,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pred_xgb = model_xgb.predict(X_test_tfidf)

# %%
print(confusion_matrix(y_test,pred_xgb))
# Out:
# [[5617  325]
#  [ 166 5780]]

# %%
print(classification_report(y_test,pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      5942
#            1       0.95      0.97      0.96      5946
#
#     accuracy                           0.96     11888
#    macro avg       0.96      0.96      0.96     11888
# weighted avg       0.96      0.96      0.96     11888

# %%
#SVM Model
from sklearn.svm import LinearSVC
lin_svm = LinearSVC()
lin_svm.fit(X_train_tfidf,y_train)
# Out:
# LinearSVC()

# %%
pred_svm = lin_svm.predict(X_test_tfidf)

# %%
print(confusion_matrix(y_test,pred_svm))
# Out:
# [[5785  157]
#  [  23 5923]]

# %%
print(classification_report(y_test,pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      5942
#            1       0.97      1.00      0.99      5946
#
#     accuracy                           0.98     11888
#    macro avg       0.99      0.98      0.98     11888
# weighted avg       0.99      0.98      0.98     11888

# %%
#Logistic Regression Model
from sklearn.linear_model import LogisticRegression

# %%
model_lr = LogisticRegression(random_state=42)

# %%
model_lr.fit(X_train_tfidf,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
pred_lr=model_lr.predict(X_test_tfidf)

# %%
print(confusion_matrix(y_test,pred_lr))
# Out:
# [[5688  254]
#  [  61 5885]]

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      5942
#            1       0.96      0.99      0.97      5946
#
#     accuracy                           0.97     11888
#    macro avg       0.97      0.97      0.97     11888
# weighted avg       0.97      0.97      0.97     11888

# %%
from sklearn.naive_bayes import MultinomialNB
model_nb=MultinomialNB()

# %%
model_nb.fit(X_train_tfidf,y_train)
# Out:
# MultinomialNB()

# %%
pred_nb=model_nb.predict(X_test_tfidf)

# %%
print(confusion_matrix(y_test,pred_nb))
# Out:
# [[5442  500]
#  [ 105 5841]]

# %%
print(classification_report(y_test,pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95      5942
#            1       0.92      0.98      0.95      5946
#
#     accuracy                           0.95     11888
#    macro avg       0.95      0.95      0.95     11888
# weighted avg       0.95      0.95      0.95     11888

# %% [markdown]
# ### Working on Test Data

# %%
df_test = pd.read_csv("twitter_hate_test_tweets_anuFYb8.csv")
df_test.head()
# Out:
#       id                                              tweet
# 0  31963  #studiolife #aislife #requires #passion #dedic...
# 1  31964   @user #white #supremacists want everyone to s...
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...
# 3  31966  is the hp and the cursed child book up for res...
# 4  31967    3rd #bihday to my amazing, hilarious #nephew...

# %%
df_test['processed_tweets'] = df_test['tweet'].apply(process_tweet)
df_test.head()
# Out:
#       id                                              tweet  \
# 0  31963  #studiolife #aislife #requires #passion #dedic...
# 1  31964   @user #white #supremacists want everyone to s...
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...
# 3  31966  is the hp and the cursed child book up for res...
# 4  31967    3rd #bihday to my amazing, hilarious #nephew...
#
#                                     processed_tweets
# 0  studiolife aislife requires passion dedication...
# 1  white supremacists want everyone to see the ne...
# 2  safe ways to heal your acne altwaystoheal heal...
# 3  is the hp and the cursed child book up for res...
# 4  3rd bihday to my amazing hilarious nephew eli ...

# %%
x_test_cv = count_vect.transform(X)
x_test_tfidf = transformer.transform(x_test_cv)

# %%
df_test.shape
# Out:
# (17197, 3)

# %%
len(pred_nb)
# Out:
# 11888

# %% [raw]
# df_test['pred_nb'] = [pred_nb]

# %% [raw]
# df_test[df_test['pred_nb']==1]
